# %%
from raghelper import load_key
import os 
load_key.load_key()
# 生产环境中请勿将 API Key 输出到日志中，避免泄露
print(f'''你配置的 API Key 是：{os.environ["DASHSCOPE_API_KEY"][:5]+"*"*5}''')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 load_key.load_key()
#       4 # 生产环境中请勿将 API Key 输出到日志中，避免泄露
# ----> 5 print(f'''你配置的 API Key 是：{os.environ["DASHSCOPE_API_KEY"][:5]+"*"*5}''')
#
# NameError: name 'os' is not defined

# %%
from raghelper import rag

rag.indexing()
